# %% [markdown]
# # Deliverable 1: Retrieve Weather Data

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 777

# %%
# Import the requests library.
import requests

# Import the API key.
# imports the previous directory for config.py
import sys
sys.path.insert(1, '../')
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
            # Parse the JSON and retrieve data.
            city_weather = requests.get(city_url).json()
            # Parse out the needed data.
            city_lat = city_weather["coord"]["lat"]
            city_lng = city_weather["coord"]["lon"]
            city_max_temp = city_weather["main"]["temp_max"]
            city_humidity = city_weather["main"]["humidity"]
            city_clouds = city_weather["clouds"]["all"]
            city_wind = city_weather["wind"]["speed"]
            city_country = city_weather["sys"]["country"]
            city_weather_description = city_weather["weather"][0]["description"]
            # Append the city information into city_data list.
            city_data.append({"City": city.title(),
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Country": city_country,
                              "Current Description": city_weather_description})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 16 | albany
# Processing Record 2 of Set 16 | hermanus
# Processing Record 3 of Set 16 | talnakh
# Processing Record 4 of Set 16 | sombrerete
# Processing Record 5 of Set 16 | yar-sale
# Processing Record 6 of Set 16 | lata
# Processing Record 7 of Set 16 | luz
# Processing Record 8 of Set 16 | maryville
# Processing Record 9 of Set 16 | busselton
# Processing Record 10 of Set 16 | san quintin
# Processing Record 11 of Set 16 | laylay
# Processing Record 12 of Set 16 | taiyuan
# Processing Record 13 of Set 16 | hobart
# Processing Record 14 of Set 16 | luang prabang
# Processing Record 15 of Set 16 | ribeira grande
# Processing Record 16 of Set 16 | norman wells
# Processing Record 17 of Set 16 | faya
# Processing Record 18 of Set 16 | mahebourg
# Processing Record 19 of Set 16 | kahului
# Processing Record 20 of Set 16 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 21 of Set 16 | carmelo
# Processing Record 22 of Set 16 | butaritari
# Processing Record 23 of Set 16 | ushuaia
# Processing Record 24 of Set 16 | rikitea
# Processing Record 25 of Set 16 | hithadhoo
# Processing Record 26 of Set 16 | thompson
# Processing Record 27 of Set 16 | punta arenas
# Processing Record 28 of Set 16 | esperance
# Processing Record 29 of Set 16 | mataura
# Processing Record 30 of Set 16 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 16 | tuatapere
# Processing Record 32 of Set 16 | tateyama
# Processing Record 33 of Set 16 | ancud
# Processing Record 34 of Set 16 | moranbah
# Processing Record 35 of Set 16 | mitchell
# Processing Record 36 of Set 16 | zhigansk
# Processing Record 37 of Set 16 | kerchevskiy
# Processing Record 38 of Set 16 | port hedland
# Processing Record 39 of Set 16 | conceicao do araguaia
# Processing Record 40 of Set 16 | blackwater
# Processing Record 41 of Set 16 | port lincoln
# Processing Record 42 of Set 16 | plettenberg bay
# Processing Record 43 of Set 16 | kapaa
# Processing Record 44 of Set 16 | lebu
# Processing Record 45 of Set 16 | cherskiy
# Processing Record 46 of Set 16 | east london
# Processing Record 47 of Set 16 | cam ranh
# Processing Record 48 of Set 16 | mokhsogollokh
# Processing Record 49 of Set 16 | atuona
# Processing Record 50 of Set 16 | vaini
# Processing Record 1 of Set 17 | okha
# Processing Record 2 of Set 17 | port alfred
# Processing Record 3 of Set 17 | davao
# Processing Record 4 of Set 17 | neiafu
# Processing Record 5 of Set 17 | sartell
# Processing Record 6 of Set 17 | opuwo
# Processing Record 7 of Set 17 | klaksvik
# Processing Record 8 of Set 17 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 17 | shelburne
# Processing Record 10 of Set 17 | jamestown
# Processing Record 11 of Set 17 | victoria
# Processing Record 12 of Set 17 | kurchum
# Processing Record 13 of Set 17 | bredasdorp
# Processing Record 14 of Set 17 | torbay
# Processing Record 15 of Set 17 | moundsville
# Processing Record 16 of Set 17 | nalut
# Processing Record 17 of Set 17 | chuy
# Processing Record 18 of Set 17 | puerto ayora
# Processing Record 19 of Set 17 | cidreira
# Processing Record 20 of Set 17 | mackay
# Processing Record 21 of Set 17 | castro
# Processing Record 22 of Set 17 | pacific grove
# Processing Record 23 of Set 17 | pevek
# Processing Record 24 of Set 17 | barrow
# Processing Record 25 of Set 17 | marzuq
# Processing Record 26 of Set 17 | constitucion
# Processing Record 27 of Set 17 | halifax
# Processing Record 28 of Set 17 | vanimo
# Processing Record 29 of Set 17 | saint-georges
# Processing Record 30 of Set 17 | dikson
# Processing Record 31 of Set 17 | dalmatovo
# Processing Record 32 of Set 17 | hilo
# Processing Record 33 of Set 17 | boa vista
# Processing Record 34 of Set 17 | arraial do cabo
# Processing Record 35 of Set 17 | guatire
# Processing Record 36 of Set 17 | alberton
# Processing Record 37 of Set 17 | buala
# Processing Record 38 of Set 17 | hede
# Processing Record 39 of Set 17 | avarua
# Processing Record 40 of Set 17 | champerico
# Processing Record 41 of Set 17 | taksimo
# Processing Record 42 of Set 17 | saint-philippe
# Processing Record 43 of Set 17 | tuktoyaktuk
# Processing Record 44 of Set 17 | cambridge
# Processing Record 45 of Set 17 | uong bi
# Processing Record 46 of Set 17 | severo-kurilsk
# Processing Record 47 of Set 17 | kavieng
# Processing Record 48 of Set 17 | moron
# Processing Record 49 of Set 17 | asau
# Processing Record 50 of Set 17 | tezu
# Processing Record 1 of Set 18 | tucumcari
# Processing Record 2 of Set 18 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 18 | pacatuba
# Processing Record 4 of Set 18 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 18 | sibu
# Processing Record 6 of Set 18 | riyadh
# Processing Record 7 of Set 18 | geraldton
# Processing Record 8 of Set 18 | khatanga
# Processing Record 9 of Set 18 | new norfolk
# Processing Record 10 of Set 18 | pierre
# Processing Record 11 of Set 18 | tawau
# Processing Record 12 of Set 18 | beyneu
# Processing Record 13 of Set 18 | pemangkat
# Processing Record 14 of Set 18 | san patricio
# Processing Record 15 of Set 18 | ulladulla
# Processing Record 16 of Set 18 | metu
# Processing Record 17 of Set 18 | caucaia
# Processing Record 18 of Set 18 | hasaki
# Processing Record 19 of Set 18 | mahibadhoo
# Processing Record 20 of Set 18 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 18 | kihei
# Processing Record 22 of Set 18 | tasiilaq
# Processing Record 23 of Set 18 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 18 | deputatskiy
# Processing Record 25 of Set 18 | bosaso
# Processing Record 26 of Set 18 | quatre cocos
# Processing Record 27 of Set 18 | cape town
# Processing Record 28 of Set 18 | old saybrook
# Processing Record 29 of Set 18 | harper
# Processing Record 30 of Set 18 | georgetown
# Processing Record 31 of Set 18 | ambon
# Processing Record 32 of Set 18 | chagda
# City not found. Skipping...
# Processing Record 33 of Set 18 | yellowknife
# Processing Record 34 of Set 18 | lamar
# Processing Record 35 of Set 18 | lexington park
# Processing Record 36 of Set 18 | kirakira
# Processing Record 37 of Set 18 | nouadhibou
# Processing Record 38 of Set 18 | korem
# Processing Record 39 of Set 18 | ca mau
# Processing Record 40 of Set 18 | pizarro
# Processing Record 41 of Set 18 | senanga
# Processing Record 42 of Set 18 | ponta do sol
# Processing Record 43 of Set 18 | kodiak
# Processing Record 44 of Set 18 | provideniya
# Processing Record 45 of Set 18 | shache
# Processing Record 46 of Set 18 | selty
# Processing Record 47 of Set 18 | saldanha
# Processing Record 48 of Set 18 | manthani
# Processing Record 49 of Set 18 | lasa
# Processing Record 50 of Set 18 | rocha
# Processing Record 1 of Set 19 | sao filipe
# Processing Record 2 of Set 19 | padang
# Processing Record 3 of Set 19 | saskylakh
# Processing Record 4 of Set 19 | chase
# Processing Record 5 of Set 19 | sola
# Processing Record 6 of Set 19 | vestbygda
# City not found. Skipping...
# Processing Record 7 of Set 19 | mar del plata
# Processing Record 8 of Set 19 | ramban
# Processing Record 9 of Set 19 | hami
# Processing Record 10 of Set 19 | ekhabi
# Processing Record 11 of Set 19 | lazaro cardenas
# Processing Record 12 of Set 19 | vadso
# Processing Record 13 of Set 19 | ust-kuyga
# Processing Record 14 of Set 19 | salinopolis
# Processing Record 15 of Set 19 | xining
# Processing Record 16 of Set 19 | lavrentiya
# Processing Record 17 of Set 19 | kangasala
# Processing Record 18 of Set 19 | swan hill
# Processing Record 19 of Set 19 | carnarvon
# Processing Record 20 of Set 19 | mehamn
# Processing Record 21 of Set 19 | bethel
# Processing Record 22 of Set 19 | abilene
# Processing Record 23 of Set 19 | port keats
# Processing Record 24 of Set 19 | novobessergenevka
# Processing Record 25 of Set 19 | missoula
# Processing Record 26 of Set 19 | kaitangata
# Processing Record 27 of Set 19 | palmerston
# Processing Record 28 of Set 19 | balkhash
# Processing Record 29 of Set 19 | agadir
# Processing Record 30 of Set 19 | aras
# Processing Record 31 of Set 19 | bluff
# Processing Record 32 of Set 19 | port blair
# Processing Record 33 of Set 19 | matadi
# Processing Record 34 of Set 19 | madera
# Processing Record 35 of Set 19 | bacungan
# Processing Record 36 of Set 19 | acapulco
# Processing Record 37 of Set 19 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 19 | xapuri
# Processing Record 39 of Set 19 | bengkulu
# Processing Record 40 of Set 19 | kruisfontein
# Processing Record 41 of Set 19 | varna
# Processing Record 42 of Set 19 | ketchikan
# Processing Record 43 of Set 19 | nanortalik
# Processing Record 44 of Set 19 | qaanaaq
# Processing Record 45 of Set 19 | nagato
# Processing Record 46 of Set 19 | brookhaven
# Processing Record 47 of Set 19 | vardo
# Processing Record 48 of Set 19 | ixtapa
# Processing Record 49 of Set 19 | dunedin
# Processing Record 50 of Set 19 | capreol
# Processing Record 1 of Set 20 | omboue
# Processing Record 2 of Set 20 | teya
# Processing Record 3 of Set 20 | namibe
# Processing Record 4 of Set 20 | yulara
# Processing Record 5 of Set 20 | helong
# Processing Record 6 of Set 20 | morro bay
# Processing Record 7 of Set 20 | ayolas
# Processing Record 8 of Set 20 | balkanabat
# Processing Record 9 of Set 20 | malwan
# City not found. Skipping...
# Processing Record 10 of Set 20 | rincon
# Processing Record 11 of Set 20 | vulturesti
# Processing Record 12 of Set 20 | tiksi
# Processing Record 13 of Set 20 | lethem
# Processing Record 14 of Set 20 | svetlaya
# Processing Record 15 of Set 20 | nicoya
# Processing Record 16 of Set 20 | halalo
# City not found. Skipping...
# Processing Record 17 of Set 20 | fort nelson
# Processing Record 18 of Set 20 | komsomolskiy
# Processing Record 19 of Set 20 | arua
# Processing Record 20 of Set 20 | kurilsk
# Processing Record 21 of Set 20 | narsaq
# Processing Record 22 of Set 20 | gouyave
# Processing Record 23 of Set 20 | raudeberg
# Processing Record 24 of Set 20 | pahrump
# Processing Record 25 of Set 20 | coihaique
# Processing Record 26 of Set 20 | montmagny
# Processing Record 27 of Set 20 | shambu
# Processing Record 28 of Set 20 | petatlan
# Processing Record 29 of Set 20 | salalah
# Processing Record 30 of Set 20 | saint-pierre
# Processing Record 31 of Set 20 | wulanhaote
# City not found. Skipping...
# Processing Record 32 of Set 20 | kokopo
# Processing Record 33 of Set 20 | ewa beach
# Processing Record 34 of Set 20 | tari
# Processing Record 35 of Set 20 | aklavik
# Processing Record 36 of Set 20 | robertson
# Processing Record 37 of Set 20 | pisco
# Processing Record 38 of Set 20 | mangaldai
# Processing Record 39 of Set 20 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 20 | dekoa
# City not found. Skipping...
# Processing Record 41 of Set 20 | along
# Processing Record 42 of Set 20 | flinders
# Processing Record 43 of Set 20 | son la
# Processing Record 44 of Set 20 | one hundred mile house
# City not found. Skipping...
# Processing Record 45 of Set 20 | innisfail
# Processing Record 46 of Set 20 | fortuna
# Processing Record 47 of Set 20 | ilulissat
# Processing Record 48 of Set 20 | iqaluit
# Processing Record 49 of Set 20 | meulaboh
# Processing Record 50 of Set 20 | roebourne
# Processing Record 1 of Set 21 | gat
# Processing Record 2 of Set 21 | koraput
# Processing Record 3 of Set 21 | virginia beach
# Processing Record 4 of Set 21 | rognan
# Processing Record 5 of Set 21 | lagoa
# Processing Record 6 of Set 21 | rauma
# Processing Record 7 of Set 21 | siva
# Processing Record 8 of Set 21 | ternate
# Processing Record 9 of Set 21 | hinatuan
# Processing Record 10 of Set 21 | karkaralinsk
# City not found. Skipping...
# Processing Record 11 of Set 21 | longyearbyen
# Processing Record 12 of Set 21 | pangnirtung
# Processing Record 13 of Set 21 | orange cove
# Processing Record 14 of Set 21 | bambanglipuro
# Processing Record 15 of Set 21 | upernavik
# Processing Record 16 of Set 21 | camargo
# Processing Record 17 of Set 21 | hokitika
# Processing Record 18 of Set 21 | palmer
# Processing Record 19 of Set 21 | macusani
# Processing Record 20 of Set 21 | husavik
# Processing Record 21 of Set 21 | coahuayana
# Processing Record 22 of Set 21 | kutum
# Processing Record 23 of Set 21 | alta floresta
# Processing Record 24 of Set 21 | atasu
# Processing Record 25 of Set 21 | cap malheureux
# Processing Record 26 of Set 21 | yerbogachen
# Processing Record 27 of Set 21 | biak
# Processing Record 28 of Set 21 | juruti
# Processing Record 29 of Set 21 | leninskoye
# Processing Record 30 of Set 21 | brenham
# Processing Record 31 of Set 21 | necochea
# Processing Record 32 of Set 21 | sharjah
# Processing Record 33 of Set 21 | charters towers
# Processing Record 34 of Set 21 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 21 | scarborough
# Processing Record 36 of Set 21 | urumqi
# Processing Record 37 of Set 21 | haines junction
# Processing Record 38 of Set 21 | xichang
# Processing Record 39 of Set 21 | beringovskiy
# Processing Record 40 of Set 21 | tondano
# Processing Record 41 of Set 21 | gaziantep
# Processing Record 42 of Set 21 | kargat
# Processing Record 43 of Set 21 | bonfim
# Processing Record 44 of Set 21 | gamba
# Processing Record 45 of Set 21 | ozernovskiy
# Processing Record 46 of Set 21 | poronaysk
# Processing Record 47 of Set 21 | eskasem
# City not found. Skipping...
# Processing Record 48 of Set 21 | tougan
# Processing Record 49 of Set 21 | guerrero negro
# Processing Record 50 of Set 21 | gahanna
# Processing Record 1 of Set 22 | chancay
# Processing Record 2 of Set 22 | krasnoselkup
# Processing Record 3 of Set 22 | boca do acre
# Processing Record 4 of Set 22 | viedma
# Processing Record 5 of Set 22 | aflu
# City not found. Skipping...
# Processing Record 6 of Set 22 | san carlos de bariloche
# Processing Record 7 of Set 22 | skjervoy
# Processing Record 8 of Set 22 | maniitsoq
# Processing Record 9 of Set 22 | san andres
# Processing Record 10 of Set 22 | maldonado
# Processing Record 11 of Set 22 | omsukchan
# Processing Record 12 of Set 22 | le vauclin
# Processing Record 13 of Set 22 | selje
# Processing Record 14 of Set 22 | rio cuarto
# Processing Record 15 of Set 22 | terrace
# Processing Record 16 of Set 22 | airai
# Processing Record 17 of Set 22 | port elizabeth
# Processing Record 18 of Set 22 | palkino
# Processing Record 19 of Set 22 | konevo
# Processing Record 20 of Set 22 | yilan
# Processing Record 21 of Set 22 | mitsamiouli
# Processing Record 22 of Set 22 | pokhara
# Processing Record 23 of Set 22 | sao felix do xingu
# Processing Record 24 of Set 22 | haibowan
# City not found. Skipping...
# Processing Record 25 of Set 22 | la grande
# Processing Record 26 of Set 22 | williams lake
# Processing Record 27 of Set 22 | bambous virieux
# Processing Record 28 of Set 22 | teotitlan
# Processing Record 29 of Set 22 | soligalich
# Processing Record 30 of Set 22 | general roca
# Processing Record 31 of Set 22 | sao joao da barra
# Processing Record 32 of Set 22 | escarcega
# Processing Record 33 of Set 22 | clyde river
# Processing Record 34 of Set 22 | japura
# Processing Record 35 of Set 22 | grindavik
# Processing Record 36 of Set 22 | dickinson
# Processing Record 37 of Set 22 | hambantota
# Processing Record 38 of Set 22 | bolungarvik
# City not found. Skipping...
# Processing Record 39 of Set 22 | albanel
# Processing Record 40 of Set 22 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 22 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 22 | broken hill
# Processing Record 43 of Set 22 | chapais
# Processing Record 44 of Set 22 | half moon bay
# Processing Record 45 of Set 22 | rolim de moura
# City not found. Skipping...
# Processing Record 46 of Set 22 | sfantu gheorghe
# Processing Record 47 of Set 22 | fatikchhari
# City not found. Skipping...
# Processing Record 48 of Set 22 | fomboni
# Processing Record 49 of Set 22 | tura
# Processing Record 50 of Set 22 | paita
# Processing Record 1 of Set 23 | muroto
# Processing Record 2 of Set 23 | tulua
# Processing Record 3 of Set 23 | tacna
# Processing Record 4 of Set 23 | belen
# Processing Record 5 of Set 23 | altea
# Processing Record 6 of Set 23 | alofi
# Processing Record 7 of Set 23 | pozo colorado
# Processing Record 8 of Set 23 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 23 | chokurdakh
# Processing Record 10 of Set 23 | port macquarie
# Processing Record 11 of Set 23 | umm kaddadah
# Processing Record 12 of Set 23 | la paz
# Processing Record 13 of Set 23 | bakchar
# Processing Record 14 of Set 23 | bandarbeyla
# Processing Record 15 of Set 23 | asfi
# Processing Record 16 of Set 23 | te anau
# Processing Record 17 of Set 23 | pangody
# Processing Record 18 of Set 23 | arlit
# Processing Record 19 of Set 23 | rakiv lis
# Processing Record 20 of Set 23 | souillac
# Processing Record 21 of Set 23 | kaeo
# Processing Record 22 of Set 23 | tam ky
# Processing Record 23 of Set 23 | sioux lookout
# Processing Record 24 of Set 23 | vestmannaeyjar
# Processing Record 25 of Set 23 | parati
# Processing Record 26 of Set 23 | yeppoon
# Processing Record 27 of Set 23 | evensk
# Processing Record 28 of Set 23 | cabo san lucas
# Processing Record 29 of Set 23 | tarauaca
# Processing Record 30 of Set 23 | koslan
# Processing Record 31 of Set 23 | puerto del rosario
# Processing Record 32 of Set 23 | hovd
# Processing Record 33 of Set 23 | kazachinskoye
# Processing Record 34 of Set 23 | clarksburg
# Processing Record 35 of Set 23 | barabai
# Processing Record 36 of Set 23 | sadat
# Processing Record 37 of Set 23 | vila
# Processing Record 38 of Set 23 | margate
# Processing Record 39 of Set 23 | berdigestyakh
# Processing Record 40 of Set 23 | mangrol
# Processing Record 41 of Set 23 | salamanca
# Processing Record 42 of Set 23 | fairbanks
# Processing Record 43 of Set 23 | faro
# Processing Record 44 of Set 23 | coihueco
# Processing Record 45 of Set 23 | carman
# Processing Record 46 of Set 23 | vyazma
# Processing Record 47 of Set 23 | ano mera
# Processing Record 48 of Set 23 | attawapiskat
# City not found. Skipping...
# Processing Record 49 of Set 23 | henties bay
# Processing Record 50 of Set 23 | rungata
# City not found. Skipping...
# Processing Record 1 of Set 24 | athabasca
# Processing Record 2 of Set 24 | zyryanka
# Processing Record 3 of Set 24 | vila franca do campo
# Processing Record 4 of Set 24 | puerto leguizamo
# Processing Record 5 of Set 24 | ostrovskoye
# Processing Record 6 of Set 24 | palauig
# Processing Record 7 of Set 24 | gangotri
# City not found. Skipping...
# Processing Record 8 of Set 24 | arman
# Processing Record 9 of Set 24 | chalus
# Processing Record 10 of Set 24 | ilhabela
# Processing Record 11 of Set 24 | mount airy
# Processing Record 12 of Set 24 | polonnaruwa
# Processing Record 13 of Set 24 | milkovo
# Processing Record 14 of Set 24 | mount isa
# Processing Record 15 of Set 24 | alcacer do sal
# Processing Record 16 of Set 24 | platteville
# Processing Record 17 of Set 24 | houston
# Processing Record 18 of Set 24 | laguna
# Processing Record 19 of Set 24 | minturno
# Processing Record 20 of Set 24 | bonavista
# Processing Record 21 of Set 24 | caninde
# Processing Record 22 of Set 24 | atar
# Processing Record 23 of Set 24 | chicama
# Processing Record 24 of Set 24 | baykit
# Processing Record 25 of Set 24 | davila
# Processing Record 26 of Set 24 | vostok
# Processing Record 27 of Set 24 | coquimbo
# Processing Record 28 of Set 24 | grand gaube
# Processing Record 29 of Set 24 | poso
# Processing Record 30 of Set 24 | katsuura
# Processing Record 31 of Set 24 | eisenberg
# Processing Record 32 of Set 24 | taoudenni
# Processing Record 33 of Set 24 | zhanakorgan
# Processing Record 34 of Set 24 | gladstone
# Processing Record 35 of Set 24 | najran
# Processing Record 36 of Set 24 | samarkand
# Processing Record 37 of Set 24 | richards bay
# Processing Record 38 of Set 24 | lop buri
# Processing Record 39 of Set 24 | san matias
# Processing Record 40 of Set 24 | puerto escondido
# Processing Record 41 of Set 24 | nome
# Processing Record 42 of Set 24 | medowie
# Processing Record 43 of Set 24 | turukhansk
# Processing Record 44 of Set 24 | iranduba
# Processing Record 45 of Set 24 | san juan
# Processing Record 46 of Set 24 | tomatlan
# Processing Record 47 of Set 24 | bolobo
# Processing Record 48 of Set 24 | nikolskoye
# Processing Record 49 of Set 24 | sisimiut
# Processing Record 50 of Set 24 | palimbang
# Processing Record 1 of Set 25 | hamilton
# Processing Record 2 of Set 25 | port hardy
# Processing Record 3 of Set 25 | wonthaggi
# Processing Record 4 of Set 25 | melchor ocampo
# Processing Record 5 of Set 25 | juifang
# City not found. Skipping...
# Processing Record 6 of Set 25 | belmonte
# Processing Record 7 of Set 25 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 25 | melilla
# Processing Record 9 of Set 25 | abalak
# Processing Record 10 of Set 25 | tono
# Processing Record 11 of Set 25 | selizharovo
# Processing Record 12 of Set 25 | jacareacanga
# Processing Record 13 of Set 25 | faanui
# Processing Record 14 of Set 25 | chaah
# Processing Record 15 of Set 25 | key west
# Processing Record 16 of Set 25 | balod
# Processing Record 17 of Set 25 | boueni
# Processing Record 18 of Set 25 | am timan
# Processing Record 19 of Set 25 | broome
# Processing Record 20 of Set 25 | viseu
# Processing Record 21 of Set 25 | kristinehamn
# Processing Record 22 of Set 25 | panalingaan
# Processing Record 23 of Set 25 | san cristobal
# Processing Record 24 of Set 25 | puerto madryn
# Processing Record 25 of Set 25 | kibala
# Processing Record 26 of Set 25 | vila velha
# Processing Record 27 of Set 25 | antissa
# City not found. Skipping...
# Processing Record 28 of Set 25 | labrea
# Processing Record 29 of Set 25 | dingle
# Processing Record 30 of Set 25 | marsa matruh
# Processing Record 31 of Set 25 | kiama
# Processing Record 32 of Set 25 | simbahan
# Processing Record 33 of Set 25 | jardim
# Processing Record 34 of Set 25 | boyolangu
# Processing Record 35 of Set 25 | mount gambier
# Processing Record 36 of Set 25 | sitka
# Processing Record 37 of Set 25 | lewistown
# Processing Record 38 of Set 25 | shanghai
# Processing Record 39 of Set 25 | hofn
# Processing Record 40 of Set 25 | bangangte
# Processing Record 41 of Set 25 | sabzevar
# Processing Record 42 of Set 25 | aswan
# Processing Record 43 of Set 25 | forestville
# Processing Record 44 of Set 25 | luderitz
# Processing Record 45 of Set 25 | zheleznodorozhnyy
# Processing Record 46 of Set 25 | burica
# City not found. Skipping...
# Processing Record 47 of Set 25 | carutapera
# Processing Record 48 of Set 25 | save
# Processing Record 49 of Set 25 | harlingen
# Processing Record 50 of Set 25 | kemin
# Processing Record 1 of Set 26 | sahrak
# City not found. Skipping...
# Processing Record 2 of Set 26 | kalemie
# Processing Record 3 of Set 26 | sarangani
# Processing Record 4 of Set 26 | trairi
# Processing Record 5 of Set 26 | yining
# Processing Record 6 of Set 26 | brae
# Processing Record 7 of Set 26 | manokwari
# Processing Record 8 of Set 26 | isangel
# Processing Record 9 of Set 26 | sainte-suzanne
# Processing Record 10 of Set 26 | xai-xai
# Processing Record 11 of Set 26 | nhulunbuy
# Processing Record 12 of Set 26 | dunda
# Processing Record 13 of Set 26 | khilok
# Processing Record 14 of Set 26 | isiro
# Processing Record 15 of Set 26 | clermont
# Processing Record 16 of Set 26 | diego de almagro
# Processing Record 17 of Set 26 | tambopata
# Processing Record 18 of Set 26 | babati
# Processing Record 19 of Set 26 | reo
# Processing Record 20 of Set 26 | saint-leu
# Processing Record 21 of Set 26 | flagstaff
# Processing Record 22 of Set 26 | ornskoldsvik
# Processing Record 23 of Set 26 | gallup
# Processing Record 24 of Set 26 | ibra
# Processing Record 25 of Set 26 | myitkyina
# Processing Record 26 of Set 26 | hervey bay
# Processing Record 27 of Set 26 | marienburg
# Processing Record 28 of Set 26 | tommot
# Processing Record 29 of Set 26 | kavaratti
# Processing Record 30 of Set 26 | kota belud
# Processing Record 31 of Set 26 | calama
# Processing Record 32 of Set 26 | kota bahru
# Processing Record 33 of Set 26 | concordia
# Processing Record 34 of Set 26 | solnechnyy
# Processing Record 35 of Set 26 | huilong
# Processing Record 36 of Set 26 | inhambane
# Processing Record 37 of Set 26 | mbanza-ngungu
# Processing Record 38 of Set 26 | rafaela
# Processing Record 39 of Set 26 | port harcourt
# Processing Record 40 of Set 26 | jaru
# Processing Record 41 of Set 26 | ngukurr
# City not found. Skipping...
# Processing Record 42 of Set 26 | college
# Processing Record 43 of Set 26 | saint anthony
# Processing Record 44 of Set 26 | avera
# Processing Record 45 of Set 26 | lorengau
# Processing Record 46 of Set 26 | portland
# Processing Record 47 of Set 26 | anadyr
# Processing Record 48 of Set 26 | hella
# Processing Record 49 of Set 26 | kemi
# Processing Record 50 of Set 26 | mrirt
# City not found. Skipping...
# Processing Record 1 of Set 27 | lamu
# Processing Record 2 of Set 27 | chumphon
# Processing Record 3 of Set 27 | inuvik
# Processing Record 4 of Set 27 | kapra
# Processing Record 5 of Set 27 | muros
# Processing Record 6 of Set 27 | swellendam
# Processing Record 7 of Set 27 | batagay-alyta
# Processing Record 8 of Set 27 | mitu
# Processing Record 9 of Set 27 | merauke
# Processing Record 10 of Set 27 | bowen
# Processing Record 11 of Set 27 | caravelas
# Processing Record 12 of Set 27 | ayan
# Processing Record 13 of Set 27 | olafsvik
# Processing Record 14 of Set 27 | tiznit
# Processing Record 15 of Set 27 | bintulu
# Processing Record 16 of Set 27 | kloulklubed
# Processing Record 17 of Set 27 | ngerengere
# Processing Record 18 of Set 27 | eureka
# Processing Record 19 of Set 27 | leningradskiy
# Processing Record 20 of Set 27 | kachiry
# Processing Record 21 of Set 27 | linjiang
# Processing Record 22 of Set 27 | poddorye
# Processing Record 23 of Set 27 | sambava
# Processing Record 24 of Set 27 | whitehorse
# Processing Record 25 of Set 27 | warqla
# City not found. Skipping...
# Processing Record 26 of Set 27 | belyy yar
# Processing Record 27 of Set 27 | alghero
# Processing Record 28 of Set 27 | karasburg
# Processing Record 29 of Set 27 | havre-saint-pierre
# Processing Record 30 of Set 27 | kingsport
# Processing Record 31 of Set 27 | pala
# Processing Record 32 of Set 27 | achisay
# City not found. Skipping...
# Processing Record 33 of Set 27 | hurghada
# Processing Record 34 of Set 27 | tabas
# Processing Record 35 of Set 27 | arrecife
# Processing Record 36 of Set 27 | bathsheba
# Processing Record 37 of Set 27 | tall kayf
# Processing Record 38 of Set 27 | marystown
# Processing Record 39 of Set 27 | viligili
# City not found. Skipping...
# Processing Record 40 of Set 27 | marrakesh
# Processing Record 41 of Set 27 | osa
# Processing Record 42 of Set 27 | gedo
# Processing Record 43 of Set 27 | brasilia
# Processing Record 44 of Set 27 | aykhal
# Processing Record 45 of Set 27 | ismailia
# Processing Record 46 of Set 27 | santa cruz
# Processing Record 47 of Set 27 | ituni
# City not found. Skipping...
# Processing Record 48 of Set 27 | hailun
# Processing Record 49 of Set 27 | penzance
# Processing Record 50 of Set 27 | tarime
# Processing Record 1 of Set 28 | sangar
# Processing Record 2 of Set 28 | amga
# Processing Record 3 of Set 28 | kiruna
# Processing Record 4 of Set 28 | waipawa
# Processing Record 5 of Set 28 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 28 | alice springs
# Processing Record 7 of Set 28 | tromso
# Processing Record 8 of Set 28 | gornyy
# Processing Record 9 of Set 28 | berlevag
# Processing Record 10 of Set 28 | tambura
# Processing Record 11 of Set 28 | balykshi
# Processing Record 12 of Set 28 | waconia
# Processing Record 13 of Set 28 | suhbaatar
# Processing Record 14 of Set 28 | raiganj
# Processing Record 15 of Set 28 | terra rica
# Processing Record 16 of Set 28 | poum
# Processing Record 17 of Set 28 | northam
# Processing Record 18 of Set 28 | artyk
# City not found. Skipping...
# Processing Record 19 of Set 28 | ode
# Processing Record 20 of Set 28 | rawson
# Processing Record 21 of Set 28 | gorontalo
# Processing Record 22 of Set 28 | madison
# Processing Record 23 of Set 28 | nioro
# Processing Record 24 of Set 28 | nouakchott
# Processing Record 25 of Set 28 | manitouwadge
# Processing Record 26 of Set 28 | nsukka
# Processing Record 27 of Set 28 | bend
# Processing Record 28 of Set 28 | bethanien
# Processing Record 29 of Set 28 | ivolginsk
# Processing Record 30 of Set 28 | masallatah
# Processing Record 31 of Set 28 | nurlat
# Processing Record 32 of Set 28 | rorvik
# Processing Record 33 of Set 28 | qasigiannguit
# Processing Record 34 of Set 28 | takaka
# Processing Record 35 of Set 28 | tiarei
# Processing Record 36 of Set 28 | shenjiamen
# Processing Record 37 of Set 28 | patacamaya
# Processing Record 38 of Set 28 | tarudant
# City not found. Skipping...
# Processing Record 39 of Set 28 | olinda
# Processing Record 40 of Set 28 | itarema
# Processing Record 41 of Set 28 | loja
# Processing Record 42 of Set 28 | bilibino
# Processing Record 43 of Set 28 | buritizeiro
# Processing Record 44 of Set 28 | los llanos de aridane
# Processing Record 45 of Set 28 | mombasa
# Processing Record 46 of Set 28 | ambilobe
# Processing Record 47 of Set 28 | valparaiso
# Processing Record 48 of Set 28 | roma
# Processing Record 49 of Set 28 | tanshui
# City not found. Skipping...
# Processing Record 50 of Set 28 | mandiana
# Processing Record 1 of Set 29 | goderich
# Processing Record 2 of Set 29 | aksay
# Processing Record 3 of Set 29 | tadine
# Processing Record 4 of Set 29 | zhaodong
# Processing Record 5 of Set 29 | ferry pass
# Processing Record 6 of Set 29 | peniche
# Processing Record 7 of Set 29 | alotau
# City not found. Skipping...
# Processing Record 8 of Set 29 | arak
# Processing Record 9 of Set 29 | portobelo
# Processing Record 10 of Set 29 | beboto
# Processing Record 11 of Set 29 | baiyin
# Processing Record 12 of Set 29 | high level
# Processing Record 13 of Set 29 | daru
# Processing Record 14 of Set 29 | sao raimundo das mangabeiras
# Processing Record 15 of Set 29 | tongchuan
# Processing Record 16 of Set 29 | sidmouth
# Processing Record 17 of Set 29 | pochutla
# Processing Record 18 of Set 29 | lhokseumawe
# Processing Record 19 of Set 29 | warri
# Processing Record 20 of Set 29 | shahreza
# Processing Record 21 of Set 29 | rach gia
# Processing Record 22 of Set 29 | fevralsk
# City not found. Skipping...
# Processing Record 23 of Set 29 | lakes entrance
# Processing Record 24 of Set 29 | saryshagan
# City not found. Skipping...
# Processing Record 25 of Set 29 | abu samrah
# Processing Record 26 of Set 29 | imola
# Processing Record 27 of Set 29 | katobu
# Processing Record 28 of Set 29 | kirn
# Processing Record 29 of Set 29 | egvekinot
# Processing Record 30 of Set 29 | mayumba
# Processing Record 31 of Set 29 | falealupo
# City not found. Skipping...
# Processing Record 32 of Set 29 | orange
# Processing Record 33 of Set 29 | gimli
# Processing Record 34 of Set 29 | camacha
# Processing Record 35 of Set 29 | westport
# Processing Record 36 of Set 29 | cockburn town
# Processing Record 37 of Set 29 | tutoia
# Processing Record 38 of Set 29 | mecca
# Processing Record 39 of Set 29 | yumen
# Processing Record 40 of Set 29 | sungaipenuh
# Processing Record 41 of Set 29 | banda aceh
# Processing Record 42 of Set 29 | mirnyy
# Processing Record 43 of Set 29 | bilma
# Processing Record 44 of Set 29 | jishou
# Processing Record 45 of Set 29 | zhanaozen
# Processing Record 46 of Set 29 | hebertville
# City not found. Skipping...
# Processing Record 47 of Set 29 | kudahuvadhoo
# Processing Record 48 of Set 29 | awbari
# Processing Record 49 of Set 29 | muli
# Processing Record 50 of Set 29 | shiraoi
# Processing Record 1 of Set 30 | wilmington
# Processing Record 2 of Set 30 | ambalavao
# Processing Record 3 of Set 30 | santa isabel
# Processing Record 4 of Set 30 | kieta
# Processing Record 5 of Set 30 | derzhavinsk
# Processing Record 6 of Set 30 | toliary
# City not found. Skipping...
# Processing Record 7 of Set 30 | ponta delgada
# Processing Record 8 of Set 30 | saint-francois
# Processing Record 9 of Set 30 | jujuy
# City not found. Skipping...
# Processing Record 10 of Set 30 | oktyabrskoye
# Processing Record 11 of Set 30 | puerto narino
# Processing Record 12 of Set 30 | aitape
# Processing Record 13 of Set 30 | pec
# Processing Record 14 of Set 30 | chekhov
# Processing Record 15 of Set 30 | mariental
# Processing Record 16 of Set 30 | salto
# Processing Record 17 of Set 30 | guilin
# Processing Record 18 of Set 30 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 30 | oksfjord
# Processing Record 20 of Set 30 | marsh harbour
# Processing Record 21 of Set 30 | khash
# Processing Record 22 of Set 30 | oussouye
# Processing Record 23 of Set 30 | adrar
# Processing Record 24 of Set 30 | tanout
# Processing Record 25 of Set 30 | cansancao
# Processing Record 26 of Set 30 | manzhouli
# Processing Record 27 of Set 30 | flin flon
# Processing Record 28 of Set 30 | saint-augustin
# Processing Record 29 of Set 30 | maraa
# Processing Record 30 of Set 30 | menongue
# Processing Record 31 of Set 30 | pincher creek
# Processing Record 32 of Set 30 | lac du bonnet
# Processing Record 33 of Set 30 | diamantino
# Processing Record 34 of Set 30 | bogorodskoye
# Processing Record 35 of Set 30 | wau
# Processing Record 36 of Set 30 | maragogi
# Processing Record 37 of Set 30 | lompoc
# Processing Record 38 of Set 30 | roding
# Processing Record 39 of Set 30 | bealanana
# Processing Record 40 of Set 30 | touros
# Processing Record 41 of Set 30 | okato
# Processing Record 42 of Set 30 | offa
# Processing Record 43 of Set 30 | gizo
# Processing Record 44 of Set 30 | steyr
# Processing Record 45 of Set 30 | hutchinson
# Processing Record 46 of Set 30 | stoyba
# City not found. Skipping...
# Processing Record 47 of Set 30 | ngatea
# Processing Record 48 of Set 30 | quibdo
# Processing Record 49 of Set 30 | omama
# Processing Record 50 of Set 30 | saint george
# Processing Record 1 of Set 31 | san agustin
# Processing Record 2 of Set 31 | funadhoo
# Processing Record 3 of Set 31 | pontes e lacerda
# Processing Record 4 of Set 31 | ikalamavony
# Processing Record 5 of Set 31 | narasannapeta
# Processing Record 6 of Set 31 | kalmunai
# Processing Record 7 of Set 31 | sorvag
# City not found. Skipping...
# Processing Record 8 of Set 31 | dryden
# Processing Record 9 of Set 31 | huarmey
# Processing Record 10 of Set 31 | umarkot
# Processing Record 11 of Set 31 | nishihara
# Processing Record 12 of Set 31 | rio grande
# Processing Record 13 of Set 31 | djambala
# Processing Record 14 of Set 31 | alyangula
# Processing Record 15 of Set 31 | zhanatas
# City not found. Skipping...
# Processing Record 16 of Set 31 | tabiauea
# City not found. Skipping...
# Processing Record 17 of Set 31 | nuuk
# Processing Record 18 of Set 31 | kantabanji
# Processing Record 19 of Set 31 | mingguang
# Processing Record 20 of Set 31 | juegang
# Processing Record 21 of Set 31 | surgut
# Processing Record 22 of Set 31 | mirabad
# Processing Record 23 of Set 31 | tubruq
# City not found. Skipping...
# Processing Record 24 of Set 31 | freetown
# Processing Record 25 of Set 31 | takhtamygda
# Processing Record 26 of Set 31 | togur
# Processing Record 27 of Set 31 | veinticinco de mayo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0       Albany      US  42.60  -73.97     48.99        71         100
# 1     Hermanus      ZA -34.42   19.23     64.00        75         100
# 2      Talnakh      RU  69.49   88.40     10.40        85          40
# 3   Sombrerete      MX  23.63 -103.65     72.54        30           1
# 4     Yar-Sale      RU  66.83   70.83      3.90        94          23
# 5         Lata      PT  40.16   -8.33     55.99        87          20
# 6          Luz      BR -19.80  -45.69     77.59        62           2
# 7    Maryville      US  35.76  -83.97     64.00        39          90
# 8    Busselton      AU -33.65  115.33     45.00        97           3
# 9  San Quintin      MX  30.48 -115.95     65.23        53           0
#
#    Wind Speed Current Description
# 0        4.21     overcast clouds
# 1        5.99     overcast clouds
# 2       24.61          light snow
# 3       14.47           clear sky
# 4        9.17          few clouds
# 5        1.12          few clouds
# 6        5.79           clear sky
# 7        3.36     overcast clouds
# 8        7.38           clear sky
# 9       10.27           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)
